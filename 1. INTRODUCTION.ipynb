# %% [markdown]
# ---
# # **💻 INTRODUCTION**
# ---

# %% [markdown]
# Antigamente **Ciência de Dados (Data Science)** era sinônimo de aplicações estatísticas em dados digitais, uma vez que se baseava apenas em utilizar fundamentação estatística em dados estruturalmente armazenados. Nos últimos anos o termo Ciência de Dados começou a se tornar mais independente e visto como uma área interdisciplinar envolvendo estatística, computação e gestão da informação.
#
# Como Ciência de Dados é um termo recente e complexo, ainda não há uma definição oficial que consiga abranger todas suas camadas, principalmente por estar em constante evolução. Entretanto é possível considerar Ciência de Dados como a área de gerenciamento, manipulação e tratamento de grandes volumes de dados digitais para a obtenção de análises e informações úteis. Ou seja, a ciência que enxerga dados como um recurso que pode ser coletado de forma bruta e transformada em informação valiosa. Esse processo pode ser chamado de **Data Management**.
#
# ![image.png](data:image/png;base64,...)
#
# Dentro dessa área, há diversas definições, ferramentas e metodologias para as incontáveis aplicações possíveis, uma vez que o dado possuí formatos diversos, como bytes, textos, documentos, imagens, audios e videos. Além disso, vale ressaltar que Ciência de Dados avança juntamente com **Estatística, Inteligência Artificial, Computação na Nuvem e Inteligência de Negócios**, sendo necessário conhecimentos nessas múltiplas áreas para um entendimento pleno e abrangente.

# %% [markdown]
# ---
# # **🧰 TOOLS AND ENVIRONMENTS**
# ---

# %% [markdown]
# Na área de dados, a linguagem de programação mais utilizada é o Python juntamente com programas, distribuições, estruturas, serviços e ambientes voltados para aplicações e implementações envolvendo ciência de dados. Um serviço amplamente utilizado é o Notebook:
# *  **Notebook:** É um ambiente virtual de Literate Programming para programação que ganhou popularidade com o Python no Projeto Jupyter, sendo essa ideia com origem no IPython para suportar inicialmente Julia, Python e R. Esse serviço de computação interativa gera uma arquivo semelhante a um JSON com término em .ipynb sendo caracterizado por Cells de Markdown (Texto) e Code (Código). Possui interação pela web e é utilizado principalmente pelo Jupyter Notebook, Google Colab, Apache Zeppelin e Kaggle Notebook.

# %% [markdown]
# ---
# ## **🔼 PYTHON LIBRARIES**
# ---

# %% [markdown]
# ---
# ### **▶ Numpy**
# ---

# %% [markdown]
# Biblioteca para Computação Científica com Operações Matemáticas e para Tratamento de Dados. Por conta dos altos volumes de dados e processamentos dessas operações, o NumPy tem foco no desempenho, assemelhando-se com funções de linguagens como C (Cython). Por exemplo, os Arrays do NumPy possuem tamanho fixo e mesmo tipo.

# %%
import numpy as np

# %% [markdown]
# ---
# ### **▶ Pandas**
# ---

# %% [markdown]
# Biblioteca para manipulação e análise de dados. Apesar da flexibilidade e capacidade de utilizar matrizes dinâmicas com tipos de dados diferentes, o pandas consegue ainda ser altamente otimizada com base nas operações da linguagem C/Cython.
#
# O Pandas utiliza o objeto **Data Frame** que possui facilidade de uso e manipulação de dados. Além do desempenho, é extremamente útil em aplicações de Machine Learning, Análise de Grandes Volumes de Dados e Álgebra Relacional. Um DataFrame é uma matriz de dados, a matriz unilateral, ou vetor, é chamada de **Series**.

# %%
import pandas as pd

# %% [markdown]
# ---
# ### **▶ PySpark**
# ---

# %% [markdown]
# Apache Spark é um Framework de processamento de dados utilizando computação distribuída para criação de clusters com ênfase em paralelismo e tolerância a falha com sua distribuição para python chamada de PySpark. Sua arquitetura chama Resilient Distributed Dataset (RDD) e é disponível em Python, R, Java e sua derivação funcional Scala. Por ser um sistema distribuído, exige a utilização de Cloud e por isso é popular em processamento de Big Data.
#
# O Spark Core é a fundação de quatro tipos/distribuições de Spark:
# *  **Spark Streaming:** Utilizado em processamentos de dados de uma série temporal, geralmente recebendo pacotes de dados sequenciais.
#
# *  **Spark ML Library:** Utilizado para aplicações de machine learning em processamentos de dados.
#
# *  **Spark SQL:** Utilizado para processamentos de dados tabulados em bancos de dados.
#
# *  **Spark GraphX:** Utilizado para processamentos em estruturas de gráfos.

# %% [markdown]
# O Spark possui as estruturas padrões de dados como Data Frame e Serie, só que diferentemente do Pandas, essas estruturas são imutáveis, o que garante a tolerância a falha. A duas operações que essas estruturas podem sofrer no Spark:
# *  **Transformation:** É um processo sequencial em espera de transformação da estrutura de dados.
# *  **Actions:** Efetivação da pilha de transformações, cada processo gera uma nova estrutura.
#
# As transformações acompanhadas da ação é chamada de **Lazy Evaluation**.

# %%
# !pip install -q pyspark
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
import pyspark.sql as sp

spark = sp.SparkSession.builder.master("local[1]").appName("SparkByExamples.com").getOrCreate()

# %%
rows = [('Maria', 25, 3000.0), ('John', 47, 8500.0), ('Greg', 66, 6105.87)]
columns = ['Name', 'Age', 'Contribution']

dataset = spark.createDataFrame(data=rows, schema=columns)
dataset.show(5)
# Out:
# +-----+---+------------+
# | Name|Age|Contribution|
# +-----+---+------------+
# |Maria| 25|      3000.0|
# | John| 47|      8500.0|
# | Greg| 66|     6105.87|
# +-----+---+------------+

# %%
#from pyspark.sql import functions as f
coll = sp.functions.col("Age")
dataset.where(coll > 30).show()
# Out:
# +----+---+------------+
# |Name|Age|Contribution|
# +----+---+------------+
# |John| 47|      8500.0|
# |Greg| 66|     6105.87|
# +----+---+------------+

# %% [markdown]
# ---
# ## **🔼 ANACONDA**
# ---

# %% [markdown]
# Anaconda é uma distribuição em Python e R para computação científica com forte utilizações em Data Science, Machine Learning e Data Processing. Utiliza pacotes e um Package Management System chamado Conda para facilitar a sua utilização e integrar o conjunto das ferramentas.
#
# A distribuição possui ainda uma interface chamada de Anaconda Navigator, além de armazenamentos em Cloud análogo ao PyPl. O ambiente já contem documentações de aprendizado, além de diversos programas para a área de dados.

# %% [markdown]
# ---
# ## **🔼 KAGGLE**
# ---

# %% [markdown]
# Kaggle é um ambiente de ciência de dados com ênfase em criar uma comunidade para aprendizado e competições. Possui datasets, modelos e projetos compartilhados em seu [site](https://https://www.kaggle.com/). Além disso tem uma integração com um Kaggle Notebook para a criação de projetos pelo comunidade e cursos ofertados.

# %% [markdown]
# ---
# ## **🔼 AIRFLOW**
# ---

# %% [markdown]
# o Apache Airflow é uma ferramenta gratuita e aberta de gerenciamento de fluxo de operações para pipelines de dados. Teve origem em 2014 pela Airbnb para solucionar seus problemas de fluxos de operações, se tornando posteriormente um projeto da Apache. É utilizado para orquestrar pipelines criadas chamadas de **DAGs** (Grafos Acíclicos Direcionados) com cada grafo sendo uma **Task** que é compilada por um **Operator**.
#
# ![image.png](data:image/png;base64,...)

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator # Operator to compile the Task
from airflow.operators.python import BranchPythonOperator # Operator to compile and branch into other Tasks
from airflow.operators.bash import BashOperator # Terminal Instruction Operator
from airflow.operators.email import EmailOperator # Operator sends an email
from airflow.providers.http.operators.http import HttpOperator # Operator calls an HTTP endpoint
from airflow.providers.mysql.operators.mysql import MySqlOperator # Operator executes an SQL code

def Task1():
  var = 0
  # Do Something
  return var

def Task2(task_instance):
  var = task_instance.xcom_pull(task_ids='Task1') # Pull Variable from other Task
  if var > 0:
    return 'Task3'
  if var < 0:
    return 'Task4'
  else:
    return 'Task5'

with DAG('Name ID', start_date='Date to Start', schedule_interval='Start Interval', catchup=False) as dag:
  Task1 = PythonOperator(task_id='Task1', python_callable=Task1)
  Task2 = BranchPythonOperator(task_id='Task2', python_callable=Task2)
  Task3 = BashOperator(task_id='Task3', bash_command="Shell Instruction")
  Task4 = BashOperator(task_id='Task4', bash_command="Shell Instruction")
  Task5 = BashOperator(task_id='Task5', bash_command="Shell Instruction")

  Task1 >> Task2 >> [Task3, Task4, Task5]

# %% [markdown]
# ---
# ## **🔼 OTHERS**
# ---

# %% [markdown]
# ---
# ### **▶ JetBrains Data IDE's**
# ---

# %% [markdown]
# *  **DataSpell:** Possui integração com Conda para combinar o uso da IDE PyCharm e o Jupyter Notebook fornecendo tabelas interativas, interface de usuário e assitência de código voltados para a área de dados.
#
# *  **DataLore:** É uma plataforma colaborativa e intuitiva para análise de dados e Business Inteligence (BI). Possui integração com Jupyter Notebook e banco de dados com suporte em SQL.
#
# *  **IntelliJ Big Data Tools:** É um plug-in do IntelliJ IDEA feito para engenharia de dados com integração de Notebooks Zeppelin idealmente para operações envolvendo Big Datas armazenados distribuidamente e utilização de ETl's (Extract Transform Load) e Pipelines.
#
# *  **DataGrip:** Ambiente para operação de dados em database ou data-warehouse com interface para SQL.

# %% [markdown]
# ---
# ### **▶ Orange**
# ---

# %% [markdown]
# Orange é um Framework para mineração e visualização de dados com interatividade por janelas e widgets. Foi criado por uma Universidade da Slovenia com intuito de ser open-source e extremamente intuitivo em suas diversas ferramentas.

# %% [markdown]
# ---
# ### **▶ Hugging Face**
# ---

# %% [markdown]
# Hugging Face é um ambiente de compartilhamento de modelos e conjuntos de dados para machine learning. Possui uma vasta biblioteca de modelos pre-treinados e transformers, com ênfase em Natural Processing Languagem.
#
# Seus datasets e modelos estão em seu [site](https://huggingface.co) o que garante uma comunidade forte para compartilhamento, instrução e interação entre pessoas.
#
# Utiliza a biblioteca **transformers**:

# %%
# !pip install -q transformers

# %%
import transformers
