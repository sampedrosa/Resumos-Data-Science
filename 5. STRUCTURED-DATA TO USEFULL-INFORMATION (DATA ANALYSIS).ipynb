# %% [markdown]
# ---
# # **📊 STRUCTURED-DATA TO USEFULL-INFORMATION (DATA ANALYSIS)**
# ---

# %% [markdown]
# Data Analysis é um termo complexo que muitas vezes pode se referir a uma análise após os dados já serem armazenados para uso ou envolver todas as etapas do processamento de dados, mas a realidade é que isso varia de acordo com o caso. Em uma empresa que aplica ETL para obter seus dados no sistema para serem posteriormente usados, a Análise de Dados se encaixa no perfil de apenas lidar com os esses dados já armazenados, enquanto a Engenharia de Dados com os processos anteriores. Já em casos de menores empresas ou usos em projetos separados, a Análise de Dados pode ser responsável por todo o processo, desde a coleta até a tomada de decisões. Dessa maneira, setores e empresas ficam responsáveis por determinar atribuições da maneira organizacional que mais a beneficía.
#
# No caso de ter os dados estruturados já disponíveis ou de fácil acesso, a Análise de Dados ainda necessita de lidar com etapas anteriores dependendo da aplicação que for usar, uma vez que dificilmente os dados são armazenados já perfeitos para diferentes tipos de usos. Restando então aplicar menores etapas de pré-processamento (Data Preprocessing) para a utilização nas análises, aplicações, modelagens e visualizações.

# %% [markdown]
# ---
# ## **🔼 DATA EXPLORATION**
# ---

# %% [markdown]
# A Exploração de Dados, muitas vezes chamado de Ciência de Dados ou até mesmo apenas Análise de Dados, é a parte do processo que exige mais pesquisa, inovação e estudos por envolver conhecimentos modernos de Estatística e Inteligência Artificial, as vezes até de Economia ou Marketing dependendo da aplicação.
#
# A tomada de decisões para saber qual e como aplicar um modelo em quais tipos de cenários é o maior desafio, uma vez que exige criatividade e um pensamento inovativo, além de muitos testes e aperfeiçoamentos. Como o foco da Análise de Dados e das últimas etapas desses processos de manipulação é obter informações que direcionam tomadas de decisões ou conclusões que antes não eram claras, a Exploração de Dados é responsável pelos estudos de como obter tudo isso de uma forma analítica e exploratória.

# %% [markdown]
# ---
# ## **🔼 DATA VISUALIZATION**
# ---

# %% [markdown]
# ---
# ### **▶  Recomendations**
# ---

# %% [markdown]
# **A.C.C.E.N.T**
# *    **A**pprehension (Perpecpção): Compreensão da relação lógica das variáveis
#  * Área de foco visual é sempre de cima-baixo e esquerda-direita.
# *    **C**larity (Clareza): Distinção dos elementos com sua respectiva importância.
#  *    Paleta de cores em vez de cores fortes.
#  *    Considerar que existem pessoas com daltonismo e problemas de visão.
# *    **C**onsitency (Consistência): Semelhança visual com outros gráficos e figuras.
#  *    Variar dados e relações com gráficos diferentes, mas manter design.
# *    **E**fficiency (Eficiência): Transformar uma informação complexa em algo de fácil vizualização.
#  * Ordenar valores por escala de cor em vez de cores diferentes.
# *    **N**ecessity (Necessidade): Minimalismo, manter apenas o importante.
#  *    Não mais que 20 números por gráfico.
#  * Destacar apenas dados.
# *    **T**ruthfullness (Veracidade): Precisão e escala corretos.

# %% [markdown]
# ---
# ### **▶  Charts and Graphs**
# ---

# %% [markdown]
# **Gráficos de Barras (Bar Chart)**
# Ideal para mostrar classes diferentes na base com seu respectivo alcance. Uma forma de comparar as classes entre sí. Exemplo: Quatro filiais com seu respectivo lucro anual.
#
# **Gráficos de Linhas (Line Charts)**
# Ideal para análise de dados contínua ou dados discretos com aproximação matemática contínua. Também para processos evolutivos/mudanças de alguma variável/classe. Exemplo: População mundial ao longo de vários anos.
#
# **Gráficos de Setores (Pie Chart)**
# Também chamados de gráfico de "pizza", é apenas recomendado a utilização em situações com poucas classes e em que uma delas se destaca em porcentagem e recebe o foco. Mais utilizado como marketing ou visualização de impacto. Exemplo: 84% do lixo nos oceanos é produzido na Ásia, 8% na América, 4% África, 3% Europa e 1% Oceania.
#
# **Gráficos de Dispersão (Scatter)**
# Ideal para mostrar diferentes variáveis, falhando visualmente apenas quando há dispersão baixa e a amostragem (ponto) se misturam. Exemplo: Relação pigmentação da juba de leões com sua produção de testosterona.

# %% [markdown]
# ---
# #### **Histogram**
# ---

# %% [markdown]
# **Histograma**
#
# Distribuição de Frequência gráfica em barras que representam um conjunto de dados. Base é a Classe e a Altura a Frequência.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# #### **Heat Map**
# ---

# %% [markdown]
# Gráfico de calor, idealmente utiizado em representações com mapas reais. Utiliza uma palheta ou escala de cores para determinar a grandeza de uma variável. Sua grande vantagem é em como o ser humano consegue identificar mais facilmente diferença de cores do que escalas e números.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# #### **Boxplot**
# ---

# %% [markdown]
# **Diagrama de Caixa**
#
# Visualização de Distribuição de Dados por Quartils:
# Q1 = 25%, Q2 = 50% (Mediana) e Q3 = 75%
#
# A caixa começa no Q1 e termina no Q3. Ou seja, possui largura IQR = Q3 - Q1.
# Os bigodes/whisker são as linhas que determinam o Limite Inferior e Superior:
# LI = Q1 - 1,5*IQR, LS = Q3 + 1,5*IQR (O valor 1,5 pode variar).
#
# Valores menores ou maiores que os limites são os Outliers.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ### **▶ Python Visualization Libraries**
# ---

# %% [markdown]
# ---
# #### **MatPlotLib.PyPlot**
# ---

# %% [markdown]
# Uma biblioteca de gráficos e visualização de dados, muito utilizada na área científica e matemática.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Global Population over the Years
population = pd.read_csv("https://gist.githubusercontent.com/sjl/2394233/raw/a1d835f4d65357ff6632ad924e7180c5916b37e2/world-population.csv")
population = pd.DataFrame(population["population"].values, index=population["year"])
population = population.loc[(population.index > 0)] # Gets only after Christ years
population.index.name = "Years"
population.columns = ["Population"]

# NBA Players Statistics in 2019
players = pd.read_csv("https://raw.githubusercontent.com/dataprofessor/data/master/nba-player-stats-2019.csv")

# %% [markdown]
# O pyplot guarda o gráfico como um endereço de memória específica. Ou seja, no momento que é criado, o endereço fica ocupado e não permite interações múltiplas. Partindo desse endereço, é possível fazer as alterações e chamadas de funções, incluindo a de mostrar.
#
# Os recursos podem ser usados inclusive juntos com outras bibliotecas de plottagem.

# %%
plt.figure(figsize=(8, 4)) # Size (width, height), figure always before plot
plt.plot(population) # Create Memory Graph
plt.xlim(0, 2020) # (min, max) from "x" visualization
plt.ylim(0, 3000000000) # (min, max) "y" visualization
plt.xlabel("Years") # Label of X
plt.ylabel("Population") # Label of Y
plt.title("Population/Years") # Graph Title
plt.show() # Show the Graph

# %% [markdown]
# ---
# #### **Multiple Graphs**
# ---

# %% [markdown]
# Os gráficos múltiplos do Pyplot funcionam de forma semelhante com gráfico único. É carregado um gráfico pro vez e plotado no final.

# %%
# Multiple Graphs
plt.subplot(2, 2, 1) # (total rows, total cols, position) of the Graph
plt.subplots_adjust(wspace=0.3, hspace=0.7) # Graphs Spacing in %
plt.plot(population.loc[0:500])
plt.title("First 500 Years Population")
plt.subplot(2, 2, 2)  # (total rows, total cols, position) of the Graph
plt.plot(population.loc[0:1000])
plt.title("First Milenium Population")
plt.subplot(2, 2, 3)  # (total rows, total cols, position) of the Graph
plt.plot(population.loc[1000:2000])
plt.title("First to Second Milenium Population")
plt.subplot(2, 2, 4)  # (total rows, total cols, position) of the Graph
plt.plot(population)
plt.title("Population")
plt.show()

# %% [markdown]
# ---
# #### **Scatter**
# ---

# %%
# Scatter
plt.scatter(x=players["Age"], y=players["PTS"])
plt.xlabel("Age")
plt.ylabel("Points/Game")
# Out:
# Text(0, 0.5, 'Points/Game')

# %% [markdown]
# ---
# #### **Histograms**
# ---

# %%
# Histogram
plt.hist(players['Age'])
plt.title('NBA Players Age Histogram')
plt.xlabel('Age')
plt.ylabel('Number of Players')
# Out:
# Text(0, 0.5, 'Number of Players')

# %% [markdown]
# ---
# #### **Box Chart**
# ---

# %%
# Box Plot
plt.boxplot(players["PTS"], showfliers=True)
plt.title("Players Points/Game Box Plot")
plt.xlabel("Points/Game")
# Out:
# Text(0.5, 0, 'Points/Game')

# %% [markdown]
# ---
# #### **Seaborn**
# ---

# %% [markdown]
# Uma biblioteca baseada no matplotlib só que com mais detalhamento nos gráficos melhorando sua estética e identificação de informações, porém esses recursos consomem mais processamento do que comparado com o matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Global Population over the Years
population = pd.read_csv("https://gist.githubusercontent.com/sjl/2394233/raw/a1d835f4d65357ff6632ad924e7180c5916b37e2/world-population.csv")
population = pd.DataFrame(population["population"].values, index=population["year"])
population = population.loc[(population.index > 0)] # Gets only after Christ years
population.index.name = "Years"
population.columns = ["Population"]
mil = []
for i in population.index:
  if i < 1000:
    mil.append("First")
  else:
    mil.append("Second")
population["Milenium"] = mil

# NBA Players Statistics in 2019
players = pd.read_csv("https://raw.githubusercontent.com/dataprofessor/data/master/nba-player-stats-2019.csv")

# %%
sns.lineplot(x="Years", y="Population", data=population, linewidth=1, marker=".", markersize=10).set(title="Population Over Years", xlabel="Years", ylabel="Population in Billions")
sns.set_theme(style="white", font_scale=0.7) # Font Write

# %% [markdown]
# ---
# ##### **Multiple Graphs**
# ---

# %% [markdown]
# No Seaborn, a plottagem pode ser simultânea, mas sem a utilização dos subplots do Pyplot, os gráficos ficam por cima do outro.

# %%
population_higher = population["Population"]*1.4
population_lower = population["Population"]*0.5

sns.lineplot(population)
sns.lineplot(population_higher)
sns.lineplot(population_lower)
# Out:
# <Axes: xlabel='Years', ylabel='Population'>

# %%
# Separating with a Class
sns.lineplot(x="Years", y="Population", data=population, hue="Milenium")
# Out:
# <Axes: xlabel='Years', ylabel='Population'>

# %%
# Separating Graph with Class
sns.catplot(x="Years", y="Population", data=population, col="Milenium")

# %% [markdown]
# ---
# ##### **Scatter**
# ---

# %%
# Scatter
sns.scatterplot(x=players["Age"], y=players["3P%"])
# Out:
# <Axes: xlabel='Age', ylabel='3P%'>

# %% [markdown]
# ---
# ##### **Regression Plot**
# ---

# %%
# Regression Plot
sns.regplot(x=population.index, y=population["Population"])
# Out:
# <Axes: xlabel='Years', ylabel='Population'>

# %% [markdown]
# ---
# ##### **Histogram**
# ---

# %%
# Histogram
sns.histplot(players['Age'], kde=True, color='blue').set(title='NBA Players Age Histogram')
# Out:
# [Text(0.5, 1.0, 'NBA Players Age Histogram')]

# %% [markdown]
# ---
# ##### **Box Chart**
# ---

# %%
# Box Plot
sbr.boxplot(data=players[['2P%', '3P%', 'FT%']]).set_title('NBA Players Accuracy Box Plot')
# Out:
# Text(0.5, 1.0, 'Players Points/Game Box Plot')

# %% [markdown]
# ---
# ## **🔼 BUSINESS INTELIGENCE**
# ---

# %% [markdown]
# A inteligência de Negócio/Empresarial/Mercado ou apenas BI é um tipo de análise de dados voltado para a gestão de negócio. É um conjunto de técnicas, métodos e ferramentas para a geração de informações úteis de negócios a partir de um conjunto de dados. Ou seja, direciona o setor empresarial na tomada de decisões de coleta, organização, análise informativa/visual, compartilhamento e monitoramento a partir de dados brutos armazenados.
#
# Com a evolução da área de dados e da computação em nuvem, as ferramentas de BI estão cada vez mais amplas, eficiêntes e integradas com outras tecnologias. Por ter recursos diversos e intuitivos, é utilizada por setores de marketing, administrativo, financeiro e ciência de dados.
#
# O BI opera nos chamados **Relatórios** criados a partir de dados importados, seja em planilhas, documentos ou banco de dados. Os Relatórios geralmente possuem três abas de visualização:
# *   **Relatório de Painéis:** Exibição dos paineis, insights, gráficos gerados pelos recursos de BI, também chamado de Dashboard.
# *   **Exibição de Tabelas:** Exibição dos dados em formato de tabela/planilha. Modificações são semelhantes as feitas pelo Excel/Sheets.
# *   **Exibição de Modelo:** Exibição da modelagem de tabelas de dados sendo relacionais como em banco de dados ou não.

# %% [markdown]
# As duas maiores ferramentas de BI são:
# *  **PowerBI:** Destaca-se por integrar com outras ferramentas da Microsoft e seus servidores de nuvem Azure, mantendo um uso intuitivo para leigos ou acostumados ao Excel. Por conta disso, perde flexibilidade ao ser implantado em uma empresa que não utiliza serviços da Microsoft. Por ser uma ferramenta mais simples e abrangente, tem sua versão grátis (Free) e paga (Pro) por um preço acessível para todos. Gera relatórios com sufixo pbix.
# *  **Tableau:** Destaca-se pela sua facilidade e agilidade de uso sem perder a capacidade aprimorada para análise de dados pela integração com Python, R e Matlab, além das aplicações de IA que evoluem a cada atualização. Por ser mais complexo e pesado, é recomendada mais para analistas de dados. Possui versão grátis (Public) um pouco limitada e a versão paga (Desktop) com um preço acessível apenas para empresas e setores. Gera relatórios com sufixo twbx.
