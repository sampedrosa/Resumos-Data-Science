# %% [markdown]
# ---
# # **📚 STATISTICS**
# ---

# %% [markdown]
# ---
# ## **🔼 FUNDAMENTALS**
# ---

# %% [markdown]
# ---
# ### **▶  Definitions**
# ---

# %% [markdown]
# **Estatística Descritiva (Descriptive)**
#
# *    Descreve, resume  e organiza dados em que muitas vezes são suficientes ou suportivos para apresentação de uma ideia. Quantidades, relações de variáveis, funções discretas são maneiras de representar uma probabilidade descritiva, que, resume e descreve uma realidade. Ideal para apresentação em gráficos e tabelas.
# ---
# **Probabilística (Probabilistic)**
# *    Campo da probabilidade. Baseada em cálculos de eventos incertos, desconhecidos ou empiricamente impraticáveis. Podem ser:
#  *    **Probabilidade de Frequência ou Aleatoriedade**: Quando há uma maneira de calcular o resultado e sua previsibilidade matemática. Como jogar uma moeda ideal.
#  *    **Probabilidade Bayersiana ou Epistemológica**: Quando há diversas incertezas incalculáveis ou desconhecidas no evento, porém é possível determinar padrões e estimativas com base nas variáveis já conhecidas. Como, por exemplo, uma pessoa ganhar em um jogo de cassino várias vezes seguidas. A probabilidade disso acontecer **tende** a zero matematicamente, logo, é possível concluir que essa pessoa está utilizando de métodos ilícitos.
# ---
# **Estatística Inferencial (Inferential)**
# *    Afirmações a partir de uma amostragem de dados representativos sobre algo. Ou seja, o universo possui dados que são impossíveis ou impraticáveis de serem todos coletados, porém é possível coletar alguns que representam uma amostragem do todo. Essa amostragem pode passar por um Clustering que agrupa os dados em suas semelhanças. O grande desafio da inferência é conseguir coletar valores distintos capazes de representar bem a realidade e sua margem de erro, uma vez que nunca há precisão de 100%. Um exemplo é a estimativa eleitoral de um país, em que há consulta de uma pequena parte do eleitorado, mas que tenta representar o todo. Há duas interpretações da Inferência:
#  *    **Inferência de Frequência**: Baseada em uma frequência de eventos que acontecem, deduz uma porcentagem de chance de eventualmente acontecerem novamente. Sabe-se que a cada 300 mil anos a Terra entra em uma Era do Gelo. Deduz-se eventualmente acontecerá novamente nesse período de tempo coletado, mesmo não tendo explicações científicas nesse processo geológico.
#  *    **Inferência Bayesiana**: Avaliação de hipóteses pela máxima verossimilhança. Classificações e Regressões dos dados com objetivo de encontrar qualquer relação matemática baseada no Teorema de Bayes. É uma estimativa criada e trabalhada para satisfazer um problema. Muito utilizada em aplicações de IA, Área de Dados e Computação no geral.
#
# ---
# Além disso, a estatística pode ser:
# *    **Estatística Paramétrica**: Estatistica que não utiliza de saltos lógicos ou suposições, por conta disso, em muitos modelos é ineficaz, mas nunca está matematicamente errado.
# *    **Estatística Não-Paramétrica**: Possui suposições baseadas em frequência e aproximações por amostragem, consegue ser satisfatório quando a suposição está correta, mas matematicamente errado no quando não. Por exemplo uma amostragem de 99 dados que estão distribuidos normalmente, estima-se que o dado coletado seguinte mantenha esse padrão, enquanto que na paramétrica estima-se que o 100 dado seja indeterminado e que não seja possível determinar que o padrão é normal sem todos os dados analisados.

# %% [markdown]
# ---
# ### **▶  Elements**
# ---

# %% [markdown]
# *    **Variáveis Quantitativas**:
#  *    **Contínuas**: Reais, sem intervalo.
#  *    **Discretas**: Sinais, numeros fixos em um intervalo.
# *    **Variáveis Qualitativas**:
#  *    **Nominais**: Nomeadas, sem ordem ou hierarquia.
#  *    **Ordinais**: Com ordem ou hierarquia.
# ---
# *    **Amostragem**: Conjunto de dados que representa uma fração do todo em quantidade, mas tenta representar em semelhança com as variáveis a serem analisadas. Um elemento da amostra é chamado de Pontos Amostrais.
# *    **Espaço Amostral**: São todas as possibilidades de ocorrência.
# ---
# *   **Determinístico**: Cada entrada possui o seu domínio de saída.
# *   **Estocástico**: Cada entrada possui diferentes saídas.
# *    **Problema Meta-Heurístico**: Problema que é possível determinar a qualidade da resposta, mas é impossível ou impraticável obter um método de solução generalizada. Utiliza-se modelos e ferramentas para obter a melhor resposta ou aproximado disso. Modelos e algoritmos computacionais são ótimos para resolução desses problemas e se diferenciam na otimização.

# %% [markdown]
# ---
# ## **🔼 GENERAL STATISTICS CONCEPTS**
# ---

# %% [markdown]
# ---
# ### **▶  Measures**
# ---

# %% [markdown]
# **Moda**: Valor(es) que mais repete(m). Não há moda sem repetição.
#
# **Mediana**: Em ordem, geralmente crescente, o valor do meio. Em caso de n ser par, calcula-se a média dos dois valores do meio. Também chamado de segundo quartil ou Q2(50%). O primeiro e terceiro quartils são Q1(25%) e Q3(75%), todos calculados com os dados em ordem.
#
# **Média (x̄)**:
#
# ![image.png](data:image/png;base64,...)```
#
# **Média Ponderada (x̄p)**: Média com peso.
#
# ![image.png](data:image/png;base64,...)
#
# **Desvio Padrão (σ)**: Raiz quadrada da média da diferença do quadrado dos valores em relação á média.
# ![image.png](data:image/png;base64,...)
#
# **Variância**: É o quadrado do Desvio Padrão.
#
# **Amplitude**: Diferença do maior valor para o menor valor.

# %% [markdown]
# ---
# ### **▶  Probability**
# ---

# %% [markdown]
# **Evento Único**: Somente uma ação/evento realizado.
# ```
# P = Esperado/Possíveis
# P = P1 + P2 # Chance de acontecer E1 ou E2
# ```
# **Eventos Independentes**: Mais de um evento realizado, mas o resultado não afeta o evento seguinte.
# ```
# P = P1 * P2 # Chance de acontecer E1 e depois E2
# ```
# **Eventos Dependentes**: Mais de um evento realizado e o resultado afeta o evento seguinte.
# ```
# P = P1 * Pd2 # Chance de acontecer E1 e depois E2
# ```

# %% [markdown]
# ---
# ### **▶  Distribution**
# ---

# %% [markdown]
# ---
# #### **Normal Distribution**
# ---

# %% [markdown]
# **Distribuição Normal ou Gaussiana**: Várias aspectos do universo são ou se assemelham a uma distribuição normal que é uma função **f(x̄,σ)** relacionando desvio padrão e média.
#
# ![image.png](data:image/png;base64,...)
#
# **Distribuição Normal Z**: Uma distribuição normal com média zero e desvio padrão igual a um. Utilizada para transformar outras distribuições normais em uma generalizada. É possível achar o Z correspondente para cada Xi, usando:
#
# ![image.png](data:image/png;base64,...)
#
# Utilizando uma tabela de probabilidades da Distribuição Normal Z, é possível obter probabilidades, estimativas e análises do ponto de amostragem.
# Uma ferramenta gráfica para tentar identificar se uma função se assemelha a uma distribuição normal é o **QQ Plot** que plota uma linearidade dos quantils da função testada e da normalidade.
#
# ![image.png](data:image/png;base64,...)

# %%
from scipy.stats import norm

print(f'{norm.cdf(-1, 0, 1)*100:,.4f}%') # Probability of less then -1 with mean 0 and std 1
print(f'{norm.sf(-1, 0, 1)*100:,.4f}%') # Probability of more then -1 with mean 0 and std 1
# Out:
# 15.8655%
# 84.1345%

# %% [markdown]
# ---
# #### **Central Limit Theorem**
# ---

# %% [markdown]
# **Teorema Central do Limite**: O teorema central do limite mostra que dado uma uma Sequência de Amostragens (Am):
# ```
# A1 = {x11, x12, ..., x1n} ,  Média A1 = x̄1
# A2 = {x21, x22, ..., x2n} ,  Média A2 = x̄2
#            ...
# Am = {xm1, xm2, ..., xmn} ,  Média Am = x̄m
# ```
# O conjunto {x̄1, x̄2, ..., x̄m} forma um histograma que aproxima para uma distribuição normal a medida que 'n' e 'm' aumenta.
#
# ![image.png](data:image/png;base64,...)

# %%
from scipy.stats import norm
from scipy import stats
import seaborn as sns
import numpy as np

data = norm.rvs(size = 1000)
sns.histplot(data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# Normal Distribution Test
fig, ax = plt.subplots()
stats.probplot(data, fit=True, plot=ax)
plt.show()
stats.shapiro(data)
# Out:
# ShapiroResult(statistic=0.997530460357666, pvalue=0.13625624775886536)

# %% [markdown]
# ---
# #### **Student T**
# ---

# %% [markdown]
# Em casos de uma amostragem pequena e desvio padrão desconhecido, a distribuição começa a se distanciar de uma normal, então é utilizado a **Tabela T**.
#
# O T de Student pode ser utilizado tanto em casos de Teste de Hipóteses como em cálculos de probabilidade em geral.
#
# ![image.png](data:image/png;base64,...)

# %%
from scipy.stats import t

print(f'{t.cdf(-1, 100)*100:,.4f}%') # Probability T of less then -1 with N-1 = 100
print(f'{t.sf(-1, 100)*100:,.4f}%') # Probability T of more then -1 with N-1 = 100
# Out:
# 15.9862%
# 84.0138%

# %% [markdown]
# ---
# #### **Binomial Distribution**
# ---

# %% [markdown]
# A distribuição binomial é um tipo de distribuição para valores discretos, ou seja, há um número fixo e inteiro de valores. O nome binomial é justamente por conta dos valores possuirem apenas duas possibilidades (booleana). Para a distribuição funcionar corretamente é necessário que cada experimento do valor tenha as mesmas características, ou seja, a mesma probabilidade binomial.
#
# Ou seja, um evento com **N** experimentos independentes de probabilidade **P** (True) e probabilidade **Q=1-P** de (False). Assim, temos a seguinte fórmula para calcularmos a  distribuição de **P(x)**:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ou seja, em um evento com **N** experimentos de probabilidade **P** já definidos, temos uma função **P(x)** apenas com variável **X**. Essa função é a chamada Distribuição Binomial com formato semelhante da figura abaixo, variando apenas com **N** e **P**. Há também uma Tabela Binomial com os valores já definidos.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exemplo**: Em uma prova de 20 questões de 5 alternativas (A, B, C, D, E). Procura-se a probabilidade de "chutar" aleatoriamente todas as questões e conseguir 80% de acertos (mínimo 16 acertos). Ou seja:
# ```
# P(X>=16) = P(16) + P(17) + P(18) + P(19) + P(20)
# P = 1/5 (20% de Acerto)
# Q = 1-P (80% de Erro)
# N = 20 (Questões)
# -------------------------------
# P(16) = 1.30 E-8
# P(17) = 7.65 E-10
# P(18) = 3.19 E-11
# P(19) = 8.39 E-13
# P(20) = 1.05 E-14
# P(X>=16) = 2,1054 E-9
# Próximo de uma chance em meio bilhão.
# ```

# %%
# Binomial Simulator
# Test with N questions with random probability P of getting the right answer
import numpy as np
X = 0.8 # Minimum Percentage of Right in the Test
P = 0.2 # Correct Answer Probability
N = 20 # Number of Questions per Test

number_of_tests = 0

while(True):
  test = [] # N Questions
  for i in range(N):
    if np.random.random() > P: # (1-P) chances
      test.append(False) # Wrong Answer
    else:                      # P chances
      test.append(True)  # Correct Answer
  if np.mean(test) >= X: # When the Test has X or more Correct Answers
     print(f"One case in {number_of_tests}.")
     break
  number_of_tests = number_of_tests + 1
# Out:
# One case in 29096838.

# %%
# With Scipy, the Probabilities are more simple to call
from scipy.stats import binom

binom.pmf(16, 20, 0.2) # (want, experiments, probability), not acumulative
binom.cdf(1, 3, (1-(1/27))) # (want, experiments, probability), acumulative
# Out:
# 0.004013615810597965

# %% [markdown]
# ---
# #### **Poisson Distribution**
# ---

# %% [markdown]
# A Distribuição de Poisson é uma distribuição discreta para uma probabilidade de um determinado evento ocorrer em um intervalo de tempo ou espaço. A média dos eventos precisa ser conhecida e serem independentes do tempo passado. Como por exemplo a probabilidade de um acidente de carro acontecer em uma cidade durante um dia.
#
# A fórmula da distribuição de probabilidade em função de **X** com a **Média = λ** é:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exemplo**: Em um Maternidade Pública de uma cidade, é necessário saber quantas vagas de gestantes por dia será o suficiente para suprir a demanda com no máximo 0.5% de chance de faltar vagas durante um dia. Sabe-se que a Média (lambda λ) é de 3 gestantes por dia. Como não há um limite de gestantes, utilizamos a lógica contrária e tentamos achar um número de vagas **V** que supra 99.5% dos dias. Ou seja, a somatória de zero vagas até todas terem sido ocupadas no dia.
# ```
# Média de Gestantes ou Vagas Ocupadas (lambda) = 3
#
# Probabilidade de Faltar Vagas:
# P(x) = 0.005 = P(V) + P(V+1) + P(V+2) ...
#
# Probabilidade de Não Faltar Vagas:
# 1-P(x) = 0.995 = P(0) + P(1) + P(2) ... P(V)
# ```
# Para achar **V**, podemos utiizar um algoritmo:

# %%
import numpy as np
e = 2.718281
lambd = 3
Q = 0.995

P = 0.0
x = 0
while(P < Q): # P(0) + P(1) + ... P(P = Q)
  Px = (np.power(lambd, x) * np.power(e, -lambd))/ (np.math.factorial(x))
  P = P + Px
  print(f'P(X={x}) = {Px:,.5f} +')
  x = x + 1

print(f'---------------- \nP(X<{x}) = {P:,.5f} and V = {x-1}')
# Out:
# P(X=0) = 0.04979 +
# P(X=1) = 0.14936 +
# P(X=2) = 0.22404 +
# P(X=3) = 0.22404 +
# P(X=4) = 0.16803 +
# P(X=5) = 0.10082 +
# P(X=6) = 0.05041 +
# P(X=7) = 0.02160 +
# P(X=8) = 0.00810 +
# ----------------
# P(X<9) = 0.99620 and V = 8

# %% [markdown]
# Ou seja,
# *  P(8) = (3^8)/(e^3 * 8!) = 0.81%
# *  P(9) = (3^9)/(e^3 * 9!) = 0.27%
# *  P(X<8) = 98.81%
# *  P(X>7) = 01.19% > 0.5%
# *  P(X<9) = 99.62%
# *  P(X>8) = **00.38% < 0.5%**
#
# Então com 8 vagas na maternidade a chance de não suprir a demanda durante um dia é menor que a probabilidade máxima permitida.
#
# Isso ocorre devido ao comportamento das probabilidades de poisson formando uma distribuição. Segue a plotagem do gráfico do exemplo formando a Distribuição de Poisson:

# %%
# Poisson Graph
import seaborn as sns
probs = []

for x in range(20):
  probs.append((np.power(lambd, x) * np.power(e, -lambd))/ (np.math.factorial(x)))

sns.scatterplot(probs)
# Out:
# <Axes: >

# %%
# With Scipy, the Probabilities are more simple to call
from scipy.stats import poisson

poisson.pmf(8, 3) # (P, mean)
poisson.cdf(8, 3) # (P or less, mean)
poisson.sf(8, 3) # (P or more, mean)
# Out:
# 0.996197007938324

# %% [markdown]
# ---
# ### **▶  Confidence**
# ---

# %% [markdown]
# Supomos uma população de **P** pessoas que podem ser "Favorável" (True) ou "Contra" (False) uma lei. Consideramos que 64% seja "Favorável".

# %%
import pandas as pd
import numpy as np
import seaborn as sbr
P = 1000000

population = []

for i in range(P):
  if np.random.random() > 0.64: # 64% will be True
    population.append(False)
  else:
    population.append(True)

votes = np.average(population)
print(f'{votes} from the Population voted True')
# Out:
# 0.638897 from the Population voted True

# %% [markdown]
# Queremos realizar uma pesquisa dessa população, podemos pegar uma amostra (sample) de tamanho **N** em vez dos **P** da população. Também podemos criar **M** testes repetidos, cada um com **N** pessoas.
#
# Utilizamos a Taxa de Erro (ERRORTAX) e a função errorFunction para tornar a amostragem inclinada um pouco mais á votar "Contra" (False), já que não há teste de amostragem perfeito na vida real.
#
# Para uma realização de pesquisa como essa, é necessário determinar o nível de confiança:
#
# **Nível de Confiança**: Uma porcentagem determinada, geralmente maior que 80%, para considerar apenas os testes de amostragem que se aproximam. Ou seja, desconsidera os outliers e cria-se um intervalo de confiança. O **Alpha** é determinado pela metade de 1 - NC (TL), assim exclui-se a porcentagem Alpha dos outliers maiores e dos menores.

# %%
N, M = 20, 100
ERRORTAX = 0.05
TL = 0.95 # Trust Level
alpha = (1 - TL)/2

# %% [markdown]
# Após a definição de **P**, **N**, **M** e o **Nível de Confiança (TL)**, podemos preencher as amostras (samples) e realizar os testes, também criamos uma lista de médias para preencher a média de cada amostra.
#
# Plotamos um Box Chart para visualização.

# %%
sample = [] # size N
means = [] # shape (M, N)

for i in range(M):
  sample = np.random.choice(a=[True, False], size=N, replace=True, p=[0.64, 0.36])
  means.append(sample.mean())

print(f'Average in Samples: {np.average(means)}')
sbr.boxplot(means)
# Out:
# Average in Samples: 0.625
# <Axes: >

# %% [markdown]
# ---
# #### **Simple Confidence (Samples)**
# ---

# %% [markdown]
# Como estamos considerando testes de amostragens, podemos apenas retirar os outliers e obter facilmente com as amostragens restantes o intervalo de confiança e a margem de erro.
#
# **Intervalo de Confiança das Amostragens**: Após a determinação do nível de confiança, exclui-se os outliers e o intervalo é determinado entre o resultado do teste com menor média e o com maior média. Ou seja, considerando um nível de confiança de 95%, excluimos os 5% dos testes que mais fugiram da média e determinamos o intervalo com os 95% restantes.
#
# **Margem de Erro das Amostragens**: É a diferença que delimita o intervalo de confiança. Ou seja, IC (CI) = Média dos Resultados (+/-) Margem de Erro.

# %%
simple_means = []
for mean in means:
  simple_means.append(mean) # Using another list to simple confidence

for i in range(int(alpha*M)): # Getting the outliers
  simple_means.pop(simple_means.index(max(simple_means)))
  simple_means.pop(simple_means.index(min(simple_means)))

simpleCI = [min(simple_means)*100, max(simple_means)*100] # Samples Confidence Interval
simpleME = ((max(simple_means) - min(simple_means))/2)*100 # Samples Margin of Error

print(f'Real Population Votes: {votes} \nFOR SIMPLE CONFIDENCE: \nAverage in Samples with Trust Level: {np.average(simple_means)} \nConfidence Interval for Samples: {simpleCI[0]}% to {simpleCI[1]}% \nMargin of Error for Samples: {simpleME}%')
sbr.boxplot(simple_means)
# Out:
# Real Population Votes: 0.638897
# FOR SIMPLE CONFIDENCE:
# Average in Samples with Trust Level: 0.6260416666666667
# Confidence Interval for Samples: 40.0% to 80.0%
# Margin of Error for Samples: 20.0%
# <Axes: >

# %% [markdown]
# Como conslusão, temos que a Confiança Simples das Amostragens depende consideravelmente dos valores de **N** e **M** e do **Nível de Confiança**. Quanto maior o nível de confiança, maior vai ser o intervalo. Quanto maior for N, mais as amostragens vão ser próximas do real. Quanto maior for M, mais outliers vão existir. Um N e M altos melhoram o experimento, porém há a necessidade de mais pessoas e pode invibializar a inteção do uso da amostragem.

# %% [markdown]
# ---
# #### **Average Confidence**
# ---

# %% [markdown]
# Para médias, é possível usar uma abordagem diferente.
#
# Utilizando o Teorema Central do Limite, podemos plotar um histograma das médias das amostragens que se aproxima de uma distribuição normal. Como uma forma de aproximarmos do resultado real, excluiremos os outliers, ou seja, uma porcentagem das extremidades da distribuição normal, as mais distantes do pico/média.

# %%
sbr.histplot(means, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# **Erro Padrão**: Obtem-se da tabela Z o valor correspondente ao erro padrão. O valor é EP(SE) = Z(1 - Alpha) ou então EP(SE) = Z*(TL/2) se for uma tabela versão reduzida. Ou seja, se o Nível de Confiança é 96%, Alpha é 2% e o valor a ser procurando na tabela Z é 0.98 ou 0.48 na reduzida Z* que é igual a 2.055.
#
# **Intervalo de Confiança para Médias**: É definida pela forma seguinte, com o cálculo da margem de erro diferente da abordagem simples.
#
# **Margem de Erro para Médias**: É definida na formula seguinte, com o correspondente Z (erro padrão) vezes o desvio padrão médio dividido pela raiz do tamanho da amostra:
#
# ![image.png](data:image/png;base64,...)

# %%
import scipy.stats as st

std = np.std(means) # Standard Deviation

SE = st.norm.ppf(1-alpha) # getting Z score to be Standard Error
avgME = (SE*std)/np.sqrt(M) # Average Margin of Error

print(f'Real Population Votes: {votes*100}% \nFOR AVERAGE CONFIDENCE: \nConfidence Interval = {np.average(means)*100}% (+/-) {avgME*100}% \nOR {(np.average(means)-avgME)*100}% to {(np.average(means)+avgME)*100}%')
# Out:
# Real Population Votes: 63.988%
# FOR AVERAGE CONFIDENCE:
# Confidence Interval = 62.05% (+/-) 2.0700365402605283%
# OR 59.97996345973946% to 64.12003654026053%

# %% [markdown]
# É perceptível que a Confiança pelas Médias tende a ter resultados mais interessantes, entretanto depende de um **M** significante para que a distribuição possa se assemelhar a uma normal Z.

# %% [markdown]
# ---
# #### **Proporcional Confidence**
# ---

# %% [markdown]
# Para a Confiança de Proporção, basta apenas modificar a formula do desvio padrão para **σ = √(x̄(1-x̄))**.

# %%
import scipy.stats as st

pstd = np.sqrt(np.average(means)*(1-np.average(means))) # Proporcional Standard Deviation

SE = st.norm.ppf(1-alpha) # getting Z score to be Standard Error
avgME = (SE*pstd)/np.sqrt(M) # Average Margin of Error

print(f'Real Population Votes: {votes*100}% \nFOR AVERAGE CONFIDENCE: \nConfidence Interval = {np.average(means)*100}% (+/-) {avgME*100}% \nOR {(np.average(means)-avgME)*100}% to {(np.average(means)+avgME)*100}%')
# Out:
# Real Population Votes: 63.988%
# FOR AVERAGE CONFIDENCE:
# Confidence Interval = 62.05% (+/-) 9.510971363285389%
# OR 52.539028636714605% to 71.56097136328539%

# %% [markdown]
# ---
# ### **▶  Statistical Tests**
# ---

# %% [markdown]
# A Estatística de Teste ou Testes de Hipóteses é um procedimento de definir uma Hipótese (Hipótese Nula) e uma Contra-Hipótese (Hipótese Alternativa) sobre um conhecimento estatístico. Como por exemplo uma pesquisa de amostragem apontar algo, então o Teste de Hipótese pode ser usado com outra amostragem sendo a Hipótese o que já foi considerado pela pesquisa e a Contra-Hipótese uma suposição se a pesquisa está errada por mais ou menos. Utiliza-se uma variável chamada Nível de Significância.
#
# **Nível de Significância**: Variável definida com valores baixos. Dependendo do tamanho da amostragem de do valor escolhido, o procedimento pode errar.
#
# **Hipótese**: Hipótese a ser contestada. Exemplo: X = 23%
#
# **Contra-Hipótese**: Hipótese a ser testada. Podendo ser um resultado maior ou menor que a Hipótese. Exemplo: X > 23% ou X < 23%
#
# **Valor de Teste (P)**: Valor obtido pela obtenção na Tabela Z. Se a Contra-Hipótese sugerir maior que a hipótese, então P = 1-Z. Caso seja menor, P = Z.
#
# O resultado é obtido comparando P com o Nível de Significância. Ou seja,
# ```
# NS = Nível de Significância
# H0 = Hipótese Nula
# H1 = Contra-Hipótese
# Se H1 > H0, P = 1-Z, Se NS > P, H1 é Válido e H0 Rejeitado
# Se H1 < H0, P = Z,   Se NS < P, H1 é Válido e H0 Rejeitado
# ```
# Dessa maneira, é possível testar estatisticamente as hipóteses, desde que a amostragem seja de tamanho considerável e não seja corrompida. Há duas formas de Teste de Hipótese, uma pela Média e outra pela Proporção.

# %% [markdown]
# ---
# #### **Average Hypothesis Test (Z)**
# ---

# %% [markdown]
# Para obter o valor de P em Média, utiliza-se a fórmula e depois calcula-se o Z final pelo resultado na Tabela Z:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dessa maneira, é possível calcular **P=1-Z (Maior) ou P=Z (Menor)**.
# *  Se (H1 > H0) e (NS > P), então H1 é Válido e H0 Rejeitado. Caso não, H0 não é Rejeitado.
# *  Se (H1 < H0) e (NS < P), então H1 é Válido e H0 Rejeitado. Caso não, H0 não é Rejeitado.

# %% [markdown]
# **Exemplo**: Se uma pesquisa aponta que a média de peso de uma espécie é 64kg. Entretanto, acredita-se que esteja errado. Logo podemos determinar as hipóteses e definir um valor para o Nível de Segurança (NS).
# ```
# NS = 0.05
# H0 |Peso Médio = 64kg
# H1 |Peso Médio > 64kg
# H2 |Peso Médio < 64kg
# ```
# Obtemos a coleta de informações de uma Amostragem de tamanho N e obtemos:
# ```
# N = 100
# Média = 65kg
# Desvio Padrão = 3
# ```
# Assim, calculamos o Z = Z((Med-H0)/(DP/√N)) = Z((65-64)/(3/√100)) = Z(3,33) = 0.9996
# *  Para **H1**: P = 1-Z = 0.0004 < 0.05 Logo, **H1 é Válido e H0 Rejeitado**.
# *  Para **H2**: P = Z(Z) = 0.9996 > 0.05 Logo, **H2 não é Válido**.
#
# Conclui-se que a média de peso é maior que 64kg.

# %% [markdown]
# ---
# #### **Proporcional Hypothesis Test (Z)**
# ---

# %% [markdown]
# Para obter o valor de P em Proporção, utiliza-se a fórmula e depois calcula-se o Z final pelo resultado na Tabela Z:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dessa maneira, é possível calcular **P=1-Z (Maior) ou P=Z (Menor)**.
# *  Se (H1 > H0) e (NS > P), então H1 é Válido e H0 Rejeitado. Caso não, H0 não é Rejeitado.
# *  Se (H1 < H0) e (NS < P), então H1 é Válido e H0 Rejeitado. Caso não, H0 não é Rejeitado.

# %% [markdown]
# **Exemplo**: Se uma pesquisa aponta que 64% é favorável. Entretanto, acredita-se que esteja errado. Logo podemos determinar as hipóteses e definir um valor para o Nível de Segurança (NS).
# ```
# NS = 0.05
# H0 |Favorável 64%
# H1 |Favorável > 64%
# H2 |Favorável < 64%
# ```
# Obtemos a coleta de informações de uma Amostragem de tamanho N e obtemos:
# ```
# N = 100
# Média = 63%
# ```
# Assim, calculamos o Z = Z((Med-H0)/(√(H0*(1-H0)/N)) = Z((0.63-0.64)/(0.64*0.36/√100)) = Z(-0.0659) = 0.484
# *  Para **H1**: P = 1-Z = 0.516 < 0.05 Logo, **H1 não é Válido**.
# *  Para **H2**: P = Z(Z) = 0.484 > 0.05 Logo, **H2 é Válido e H0 é Rejeitado**.
#
# Conclui-se que menos que 63% é Favorável.

# %% [markdown]
# ---
# #### **Chi-Square χ2**
# ---

# %% [markdown]
# O Qui-Quadrado é uma distribuição que utiliza testes de hipótese que considera um intervalo aceito para que a variável em questão não seja desconsiderada de uma função **F(x)**. Ou seja, essa função possui uma "margem tolerável" de erro baseada no Nível de Significância (alpha) tanto no limite superior e inferior.
# ```
# F(x) = Função Qui-Quadrado
# Nível de Significância = alpha
# H0 | Não existe diferença significativa além do acaso
# H1 | x > k
# H2 | x < k
#
# Ao mostrar que H1 e H2 não invalidam H0, cria-se um intervalo [xi, xf]:
# Z(xi) = -alpha e Z(xf) = +alpha
# k = x +/- Acaso ou F(x) = F(k) +/- Acaso
# ```

# %% [markdown]
# A fórmula para frequência **Observada (Oi)** e **Esperada (Ei)** é:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exemplo**: Dois grupos de pessoas (A, B) foi testado para uma doença. O grupo A teve o resultado de 83 positivos e 317 negativos, já o grupo B, foi 21 positivos e 79 negativos. Realizando o algoritmo do X^2, temos:

# %%
import numpy as np
from scipy.stats import chi2_contingency

alpha = 0.05
A = [83, 317]
B = [19, 81]
test = np.array([A, B])

p = chi2_contingency(test).pvalue

if p > alpha:
  print("No significant difference between A and B")
else:
  print("There is significant difference between A and B")
# Out:
# No significant difference between A and B

# %% [markdown]
# ---
# #### **Anova (Analysis of Variance)**
# ---

# %% [markdown]
# A Análise de Variância é uma maneira de aplicação de testes em dados estatísticos com hipótese para verificar se há significância entre os dados. Ou seja, compara médias e utiliza uma **Hipótese (H0) = Não há diferença significativa entre as médias**.
#
# Como os dados podem aparecer em formatos ou em grupos diferentes, há várias formas de testes:
# *  **Teste de Student:** Apenas entre duas médias (H0 | alpha < Z(P))
# *  **Teste F**: Três ou mais médias (H0 | alpha > Z(P))
# *  **Teste de Tukey**: Identifica onde está as variações significativas.

# %% [markdown]
# **Exemplo**: Um remédio para dor de cabeça é testado em diversas pessoas separadas por grupos para testar seu funcionamento em horas até que a pessoa não tenha mais dor de cabeça. No caso de apenas dois grupos de pessoas, pode-se utilizar o Teste de Student, já no caso de mais grupos, usa-se o Teste F. No caso as pessoas são entre homens e mulheres sendo jovens, adultos e idosos, ou seja, 6 Grupos.
#
# Após a coleta de dados, cria-se a hipótese H0 para verificar se há difereça significativa entre as pessoas pelos devidos grupos. Idealmente o remédio é feito para ser eficiênte em todos os tipos de pessoas. Calcula-se Z(P) obtendo a média das horas coletadas e o desvio padrão. Depois é só comparar com o Nível de Significância (no caso como é Teste F (alpha > Z(P))) e descobrir que há variância significância entre os grupos ou não.

# %%
import pandas as pd
import numpy as np
N = 100 # People Size

treatment = []

for i in range(N):
  treat = []
  if np.random.random() > 0.5:
    treat.append("Male")
  else:
    treat.append("Female")

  if np.random.random() < 0.4:
    treat.append("Young")
  elif np.random.random() < 0.7:
    treat.append("Adult")
  else:
    treat.append("Elder")

  treat.append(int(np.random.random()*10))

  treatment.append(treat)

treatment = pd.DataFrame(treatment)
treatment.columns = ["Gender", "Age", "Hours"]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols("Hours ~ Age * Gender", data=treatment).fit()
display(sm.stats.anova_lm(model)) # Higher PR(>F) means that H0 is Valid
# Out:
#               df      sum_sq    mean_sq         F    PR(>F)
# Age          2.0    6.959584   3.479792  0.439420  0.645727
# Gender       1.0    1.596110   1.596110  0.201553  0.654504
# Age:Gender   2.0   20.442581  10.221290  1.290720  0.279902
# Residual    94.0  744.391725   7.919061       NaN       NaN

# %% [markdown]
# ---
# ## **🔼 DATA STATISTICS CONCEPTS**
# ---

# %% [markdown]
# ---
# ### **▶  Exploratory Data Analysis**
# ---

# %% [markdown]
# Análise Exploratória de Dados é uma abordagem para resumir um conjunto de dados em suas características principais, utilizando frequentemente gráficos. É uma análise aplicada aos dados que podem mostrar soluções, problemas e hipóteses que ainda não foram pensados. Basicamente usar uma análise para achar um problema oculto em vez de utilizar a análise para solucionar um problema já conhecido. Mais relacionada com intuição, criatividade e iniciativa do que com ferramentas estatísticas. Extremamente utilizado para grandes quantidade de dados.

# %% [markdown]
# ---
# ### **▶  Errors**
# ---

# %% [markdown]
# A Medida de Erros se baseia muito nas diferenças entre os dados Realizados e os Previstos. Há uma coleta de dados que são passados por processos de análise e estatística para eventualmente se adequarem a uma Previsão que será, futuramente, comparada com os mesmos tipos de dados observados da Realidade. Nessa diferença é onde se encontra os Erros que podem ser avaliados.

# %% [markdown]
# ---
# #### **Mean Errors**
# ---

# %% [markdown]
# **Erro Médio (ME)**: É a média da diferença entre o Realizado com Previsto. Não é tão utilizado devido o motivo de valores negativos e positivos poderem indicar um resultado insatisfatório.
#
# **Erro Médio Absoluto (MAE)**: É a média da diferença absoluta do Realizado com Previsto:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Erro Médio do Quadrado ou Variância (MSE)**: É a média do quadrado das diferenças, também é chamado de Variância:
#
# ![image.png](data:image/png;base64,...)
#
# **Erro Médio da Raiz Quadrada (RMSE)**: É a raid da média do quadrado das diferenças, também chamado de Desvio Padrão:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Erro Médio da Porcentagem (MPE)**: É a média da diferença percentual. Não tão utilizada devido aos negativos e positivos indicarem resultados insatisfatórios.
#
# **Erro Médio da Porcentagem Absoluta (MAPE)**: É a média da diferença percentual absoluta:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ### **▶  Regression**
# ---

# %% [markdown]
# ---
# #### **Linear Regression**
# ---

# %% [markdown]
# Regressão Linear é quando há uma equação que relaciona duas variáveis de forma linear, ou seja, crescimento ou decrescimento proporcional. Gráficamente podemos traçar uma linha da função **y=f(x)** que consegue estimar valores de dados não coletados.
#
# Padronizadamente, o **Eixo Y é o Dependente/Resposta** e o **Eixo X o Independente/Explanatória**, ou seja, queremos ver a reação de y em função da variação de x. Uma relação de duas variáveis independentes é chamado de **Colinearidade** e geralmente não gera resultados não confiáveis ou pouco informativos.
#
# A relação das variáveis, mesmo estatisticamente correta, nem sempre indica uma Relação de Efeito e Causa. Como há uma quantidade muito grande de possibilidades de correlacionamentos de variáveis distintas, a chance de alguma dessas correlações serem nada mais que coincidência é extremamente provável.
#
# Mesmo em uma relação de correlacionamento compreensível, é necessário analisar se uma variável está de fato afetando outra, uma vez que é possível que seja o contrário. Como por exemplo a relação de Pessoas Altas x Jogar Basquete Bem. As pessoas altas jogam basquete bem ou as pessoas que jogam basquete bem são altas?

# %% [markdown]
# **Exemplo**: Há uma relação direta com os minutos jogados por jogo de um jogador da NBA com a sua quantidade de pontos marcados por jogo. Uma vez que quanto mais ele joga, mais ele marca. Assim, podemos fazer uma Regressão Linear desses dados e perceber que gráficamente é possível traçar uma linha.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

players_stats = pd.read_csv("https://raw.githubusercontent.com/dataprofessor/data/master/nba-player-stats-2019.csv")
players_stats = players_stats.drop_duplicates("Player")

x = players_stats["MP"] # Minutes Played per Game
y = players_stats["PTS"] # Points per Game

sns.regplot(x=x, y=y, line_kws={"color":"red"})
# Out:
# <Axes: xlabel='MP', ylabel='PTS'>

# %% [markdown]
# **Covariância**: É a média da diferença dos dados com a média para mais de uma variável, no caso de uma variável é chamada de Variância. Para y=f(x):
#
# ![image.png](data:image/png;base64,...)
#
# **Correlação (ρ)**: Consideramos a Correlação das duas variáveis como um número **ρ** que varia entre (-1...1). Há diferentes formas de se calcular, mas a mais comum é a de Pearson que é a covariância dividido pela produto dos desvios padrões das variáveis:
#
# ![image.png](data:image/png;base64,...)
# ```
# ρ = 0  | Inexistente (Sem Relação)
# ρ = +1 | Perfeita (Crescimento)
# ρ = -1 | Perfeita Inversa (Decrescimento)
# ```
# **Coeficiente de Determinação (ρ^2)**: Como uma forma mais operacional para trabalhar com porcentagens e números absolutos, elevamos a Correlação ao quadrado e obtemos o Coeficiente de Determinação que varia entre (0...1) ou em quantos porcento de dados pode ser explicado pela relação.
# ```
# ρ^2 = 1.0       | Relação Perfeita
# 1.0 > ρ^2 > 0.7 | Relação Ótima
# 0.7 > ρ^2 > 0.5 | Relação Boa
# 0.5 > ρ^2 > 0.3 | Relação Ruim
# 0.3 > ρ^2 > 0.0 | Relação Desconsiderável
# ```

# %% [markdown]
# Sendo então a reta definida como uma função de primeiro grau, temos a Intersecção (C) e a Inclinação (B):
# ```
# y = f(x) = B*x + C
# ```
# **Inclinação (B)**: É a covariância das variáveis dividida pela variáveis a ser prevista. Ou então:
#
# ![image.png](data:image/png;base64,...)
#
# **Interceptação (C)**: Sabendo a fórmula da reta y=f(x) e a Inclinação (B ou M), basta achar a constante da Interceptação utilizando o x e y médios na fórmula:
#
# ![image.png](data:image/png;base64,...)

# %%
ρ = np.corrcoef(x.values, y.values)[0][1] # Gets the XX, XY, YX and the YY Correlations, Gets only the XY or YX
ρ2 = ρ*ρ # Coefficient of Determination

B = ρ*(np.std(y)/np.std(x)) # Inclination
C = y.mean() - B*x.mean() # Interceptation

print(f'ρ = {ρ} \nρ^2 = {ρ2} \ny = f(x) = ({B}*x) + ({C})')
# Out:
# ρ = 0.881009783411948
# ρ^2 = 0.7761782384675676
# y = f(x) = (0.5907276379781333*x) + (-2.8239052880004003)

# %% [markdown]
# **Previsão**: Com a fórmula da regressão linear, podemos fazer previsão para qualquer x de y=f(x). Para dados inferiores ao menor(x) e superiores ao maior(x), não é recomendado fazer previsões por ser uma **Extrapolação**.
# ```
# Previsão(x) = B*(x) + C
# ```
# **Resíduo**: É a diferença do dado real com a sua Previsão. Os Resíduos tendem a ter um comportamento de distribuição normal e podem ser analisados dessa forma.
# ```
# y = Previsão(x) (+/-) Resíduo
# ```
# Segue o Histograma dos Resíduos do exemplo tendendo pra uma Distribuição Normal:

# %%
residues = []

for i in range(len(x.values)):
  residue = (y.values[i] - (B*(x.values[i]) + C))
  residues.append(residue)

sns.histplot(residues, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Uma outra forma de trabalhar com Rgressão Linear é utilizando o SkLearn:

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import seaborn as sns

players_stats = pd.read_csv("https://raw.githubusercontent.com/dataprofessor/data/master/nba-player-stats-2019.csv")
players_stats = players_stats.drop_duplicates("Player")

X = players_stats["MP"].values # Minutes Played per Game
X = X.reshape(-1, 1)
y = players_stats["PTS"].values # Points per Game

model = LinearRegression()
model.fit(X, y)

predict = 30
print(f'Intercept: {model.intercept_} \nInclination: {model.coef_} \nPredict for {predict}: {model.predict([[predict]])}')
plt.scatter(X, y)
plt.plot(X, model.predict(X), color="red")
# Out:
# Intercept: -2.8239052880004056
# Inclination: [0.59072764]
# Predict for 30: [14.89792385]

# %% [markdown]
# ---
# #### **Logistic Regression**
# ---

# %% [markdown]
# A Regressão Logística é semelhante a uma Regressão Linear, porém a variável independente/explanatória tem caráter binário/booleano.
# ```
# y = f(x) = True ou False (Heaviside)
# Maior/Menor (x) = Maior/Menor Probabilidade (y)
# ```
# Em vez de uma reta apenas, a função da Regressão Logística é mistura de uma função de primeiro grau com uma função sigmoide:
# ```
# y(p) = ln(p/(1-p))
# y(x) = b1*x + b0
# ```
# Logo, podemos considerar a Regressão Logística **y(p) = y(x)**. O b0 e b1 são estimados apartir de Máxima Versossimilhança com métodos matemáticos variados de otimização, como Newton-Raphson, Limited-Memory BFGS e Stochastic Average Gradient. Igualando as funções:
#
# ![image.png](data:image/png;base64,...)
#
# Como divisão por zero e logaritmo natural de zero ou negativo são indefinições matemáticas, p assume um valor aberto entre zero até um, enquanto y possui um comportamento sigmoidal e x continua linear. Ou seja, **p indica a probabilidade de um x ser y=True ou y=False**.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exemplo**: Não são muitos jogadores da NBA que conseguem uma média de 15 pontos ou mais por jogo. Considerando a perspectiva booleana de conseguir (True) e não conseguir (False) a marca dos 15 pontos/jogo.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

players_stats = pd.read_csv("https://raw.githubusercontent.com/dataprofessor/data/master/nba-player-stats-2019.csv")
players_stats = players_stats.drop_duplicates("Player")
players_stats.loc[players_stats["PTS"] < 15.0, "PTS"] = 0
players_stats.loc[players_stats["PTS"] >= 15.0, "PTS"] = 1

x = players_stats[["MP"]].values # Minutes Played per Game
y = players_stats["PTS"].values # True for PTS equal or more then 15, False otherwise

sns.regplot(x=x, y=y, logistic=True, line_kws={"color":"red"})
# Out:
# <Axes: >

# %% [markdown]
# Dessa maneira, começamos a perceber que a probabilidade pra um jogador ter a média de mais de 15 pontos por jogo começa a ficar mais provável do que improvável quando sua média de minutos por jogo começa a passar dos 30 minutos.
#
# Com a função definida, é possível fazer Previsões com x sendo os minutos e y a probabilidade:

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(solver='liblinear', C=10.0, random_state=0).fit(x, y)
# solver can be Newton-Raphson (newton-cg), Limited-Memory BFGS (lbfgs), Stochastic Average Gradient (sag) or Stochastic Average Gradient Accelerated (SAGA)
b0 = lr.intercept_ # Interceptation
b1 = lr.coef_ # # Inclination

MP = 30
prob = lr.predict_proba([[MP]])[:, 1][0]
print(f'Player with {MP} Minutes Played per Game have {prob*100:,.2f}% of Scoring More then 15 PTS')
# Out:
# Player with 30 Minutes Played per Game have 47.04% of Scoring More then 15 PTS

# %%
# Uma forma de analisar o gráfico é que existe a distribuição logistica com o scatter dos zeros e uns
x_lr = np.linspace(x.min(), x.max(), len(x))
y_lr = 1/(1 + np.power(np.e, -(x_lr*b1 + b0)))

sns.scatterplot(x=x.ravel(), y=y)
sns.lineplot(x=x_lr, y=y_lr.ravel(), color="red")
# Out:
# <Axes: >

# %% [markdown]
# ---
# ### **▶  Time Series**
# ---

# %% [markdown]
# As Séries Temporais é uma relação de uma variável dependente/resposta com o tempo. Ou seja, um dado coletado vinculado ao seu tempo de coleta, necessário ordem desses valores e por isso sendo chamados de Séries. Dessa maneira, a variável não vai se relacionar com outra variável, mas com a variável anterior. Como por exemplo coleta de dados de temperatura em uma cidade, se em uma hora é coletado 28 graus, a proxima coleta será um valor próximo desse (dependente).
#
# A Série pode ser **Estácionária** variando em torno de uma mesma média como a temperatura climática de um dia ou não estácionária como uma bolsa de valores. Além disso, quando uma função explica exatamente o comportamento da Série, é chamada de **Determinística**, já quando há uma função estimativa e fatores desconhecidos afetando a variável, é chamado de **Estocástico**.
#
# As principais características da **Decomposição** de uma Série Temporal são:
#
# *  **Tendência**: É o comportamento a longo prazo da Série. Os dados variam entre sí, mas se aproxiasse-mos de uma regressão linear, ocorreria uma taxa de crescimento ou decrescimento.
# *  **Sazonalidade**: Quando há ciclos de tempos ou eventos que se repetem. Por exemplo preços de passagem de avião ao longo de um ano, já que aumenta em períodos de férias.
# *  **Aleatoriedade**: Na decomposição de uma Série Temporal Estocástico, é possível separar a Tendência (Trend), a Sazonalidade (Seasonal) e ainda um efeito Aleatório (Random), também chamado de erro, que é desconhecido, mas foi coletado e pode também ser analisado.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from datetime import datetime

dateparse = lambda dates: datetime.strptime(dates, '%Y-%m-%d')
oilprice = pd.read_csv("https://raw.githubusercontent.com/datasets/commodity-prices/master/data/commodity-prices.csv", usecols=["Date","Crude Oil petroleum"], parse_dates=["Date"], index_col="Date", date_parser=dateparse)
decomp = seasonal_decompose(oilprice) # Decompose the Data Frame in a Time Series

sns.lineplot(oilprice)
# Out:
# <Axes: xlabel='Date'>

# %%
# Trend
plt.subplot(3, 1, 1)
sns.lineplot(decomp.trend)

oilprice_year = oilprice.groupby([lambda x: x.year]).sum()
plt.subplot(3, 1, 2)
sns.lineplot(oilprice_year)

oilprice_year.index = oilprice_year.index/10
oilprice_year.index = oilprice_year.index.astype(int)
oilprice_decade = oilprice_year.groupby("Date").sum()
oilprice_decade.index = oilprice_decade.index*10

plt.subplot(3, 1, 3)
sns.lineplot(oilprice_decade)
# Out:
# <Axes: xlabel='Date'>

# %%
# Seasonal
sns.lineplot(decomp.seasonal)
# Out:
# <Axes: xlabel='Date', ylabel='seasonal'>

# %%
# Random/Residual
sns.lineplot(decomp.resid)
# Out:
# <Axes: xlabel='Date', ylabel='resid'>

# %% [markdown]
# ---
# #### **ARIMA**
# ---

# %% [markdown]
# O ARIMA (AutoRegressive Integrated Moving Average) é um modelo de previsão para séries temporais que substitui os dados coletados com a diferença entre os seus valores e os dados coletados anteriormente, justamente para ajustar em um modelo mais previsível e aumentar a dependência de um dado com a coleta anterior. Além disso o erro de regressão é uma combinação linear. Ou seja, temos **ARIMA(p,d,q)**:
# *  **AutoRegressivo (AR)**: Relação dos Períodos. **p** é a Ordem da Regressão.
# *  **Integração (I)**: Diferenciação. **d** é o Grau de Diferenciação.
# *  **Média Andante (MA)**: Extração de Erros dos Períodos. **q** é a Ordem da Média
#
# Os parâmetros (p,d,q) são encontrados com base em testes dentro da Série Temporal que minimizem as métricas de avaliação.

# %%
# !pip install pmdarima
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.0 MB/s eta 0:00:00
# ...

# %%
from pmdarima.arima import auto_arima

stepwise = auto_arima(oilprice, m=12, seasonal=True, trace=True, stepwise=True)
print(stepwise.aic()) # Metric Testing the Model (the lower, the best)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=2953.640, Time=1.72 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=3052.575, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2962.697, Time=0.48 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2982.113, Time=0.42 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=3050.584, Time=0.06 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=2954.721, Time=1.20 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=2955.876, Time=1.30 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=2950.414, Time=6.39 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=2948.936, Time=3.62 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=2956.131, Time=1.94 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=2958.851, Time=2.66 sec
#  ARIMA(3,1,2)(2,0,0)[12] intercept   : AIC=2950.305, Time=6.73 sec
#  ARIMA(2,1,3)(2,0,0)[12] intercept   : AIC=2950.534, Time=3.55 sec
# ...

# %%
stepwise.fit(oilprice)
predict = stepwise.predict(n_periods=60)

sns.lineplot(predict)
# Out:
# <Axes: >

# %% [markdown]
# É perceptível que para um exemplo como o preço do petróleo ao longo dos últimos anos, a previsão do ARIMA se concentra numa média com o passar do tempo, uma vez que o exemplo possui muito efeito residual. Entretanto, para casos mais próximos da última previsão de teste, o ARIMA consegue ter alguma relevância na previsibilidade.
